# %%
#Please read the comments in this notebook
#Just try to play with the data
#If you are new to all these python tools, take this week in just learning them 
#Learn pandas, matplotlib, seaborn basics from the resources in the document Python-Data-Science-Ecosystem.pdf

# %%
#Learn pandas, matplotlib, seaborn basics from the resources in the document Python-Data-Science-Ecosystem.pdf
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
news_popularity = pd.read_csv('OnlineNewsPopularity.csv') #read your data
pd.options.display.max_columns = None #This line of code just helps in displaying all columns on this notebook

# %%
news_popularity.head() #head gives you the first 5 results from your dataframe
# Out:
#                                                  url   n_tokens_title  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...               12
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...                9
# 2  http://mashable.com/2013/01/07/apple-40-billio...                9
# 3  http://mashable.com/2013/01/07/astronaut-notre...                9
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/               13
#
#     n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0                219          0.663594                1.0
# 1                255          0.604743                1.0
# 2                211          0.575130                1.0
# 3                531          0.503788                1.0
# 4               1072          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  \
# 0                   0.815385           4                2          1
# 1                   0.791946           3                1          1
# 2                   0.663866           3                1          1
# 3                   0.665635           9                0          1
# 4                   0.540890          19               19         20
#
#     num_videos   average_token_length   num_keywords  \
# 0            0               4.680365              5
# 1            0               4.913725              4
# 2            0               4.393365              6
# 3            0               4.404896              7
# 4            0               4.682836              7
#
#     data_channel_is_lifestyle   data_channel_is_entertainment  \
# 0                           0                               1
# 1                           0                               0
# 2                           0                               0
# 3                           0                               1
# 4                           0                               0
#
#     data_channel_is_bus   data_channel_is_socmed   data_channel_is_tech  \
# 0                     0                        0                      0
# 1                     1                        0                      0
# 2                     1                        0                      0
# 3                     0                        0                      0
# 4                     0                        0                      1
#
#     data_channel_is_world   weekday_is_monday   weekday_is_tuesday  \
# 0                       0                   1                    0
# 1                       0                   1                    0
# 2                       0                   1                    0
# 3                       0                   1                    0
# 4                       0                   1                    0
#
#     weekday_is_wednesday   weekday_is_thursday   weekday_is_friday  \
# 0                      0                     0                   0
# 1                      0                     0                   0
# 2                      0                     0                   0
# 3                      0                     0                   0
# 4                      0                     0                   0
#
#     weekday_is_saturday   weekday_is_sunday   is_weekend    LDA_00    LDA_01  \
# 0                     0                   0            0  0.500331  0.378279
# 1                     0                   0            0  0.799756  0.050047
# 2                     0                   0            0  0.217792  0.033334
# 3                     0                   0            0  0.028573  0.419300
# 4                     0                   0            0  0.028633  0.028794
#
#      LDA_02    LDA_03    LDA_04   global_sentiment_polarity  \
# 0  0.040005  0.041263  0.040123                    0.092562
# 1  0.050096  0.050101  0.050001                    0.148948
# 2  0.033351  0.033334  0.682188                    0.323333
# 3  0.494651  0.028905  0.028572                    0.100705
# 4  0.028575  0.028572  0.885427                    0.281003
#
#     global_rate_positive_words   global_rate_negative_words  \
# 0                     0.045662                     0.013699
# 1                     0.043137                     0.015686
# 2                     0.056872                     0.009479
# 3                     0.041431                     0.020716
# 4                     0.074627                     0.012127
#
#     avg_positive_polarity   avg_negative_polarity   title_sentiment_polarity  \
# 0                0.378636               -0.350000                  -0.187500
# 1                0.286915               -0.118750                   0.000000
# 2                0.495833               -0.466667                   0.000000
# 3                0.385965               -0.369697                   0.000000
# 4                0.411127               -0.220192                   0.136364
#
#     shares
# 0      593
# 1      711
# 2     1500
# 3     1200
# 4      505

# %%
news_popularity.columns #print the columns of dataframe
#if you see the column names below there is a space at the start of the column names
#For example: ' n_tokens_title' maybe confusing so you might convert it to 'n_tokens_title'
#This might create problems for you, so news_popularity['n_tokens_title'] will not work
#news_popularity[' n_tokens_title'] would work

#So whats the fix? You can strip the spaces
# Out:
# Index(['url', ' n_tokens_title', ' n_tokens_content', ' n_unique_tokens',
#        ' n_non_stop_words', ' n_non_stop_unique_tokens', ' num_hrefs',
#        ' num_self_hrefs', ' num_imgs', ' num_videos', ' average_token_length',
#        ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' weekday_is_monday', ' weekday_is_tuesday',
#        ' weekday_is_wednesday', ' weekday_is_thursday', ' weekday_is_friday',
#        ' weekday_is_saturday', ' weekday_is_sunday', ' is_weekend', ' LDA_00',
#        ' LDA_01', ' LDA_02', ' LDA_03', ' LDA_04',
#        ' global_sentiment_polarity', ' global_rate_positive_words',
#        ' global_rate_negative_words', ' avg_positive_polarity',
#        ' avg_negative_polarity', ' title_sentiment_polarity', ' shares'],
#       dtype='object')

# %%
#Thats how you strip the spaces
news_popularity.columns = news_popularity.columns.str.lstrip()

# %%
#print the column again and see there are no spaces
news_popularity.columns
# Out:
# Index(['url', 'n_tokens_title', 'n_tokens_content', 'n_unique_tokens',
#        'n_non_stop_words', 'n_non_stop_unique_tokens', 'num_hrefs',
#        'num_self_hrefs', 'num_imgs', 'num_videos', 'average_token_length',
#        'num_keywords', 'data_channel_is_lifestyle',
#        'data_channel_is_entertainment', 'data_channel_is_bus',
#        'data_channel_is_socmed', 'data_channel_is_tech',
#        'data_channel_is_world', 'weekday_is_monday', 'weekday_is_tuesday',
#        'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
#        'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_sentiment_polarity',
#        'global_rate_positive_words', 'global_rate_negative_words',
#        'avg_positive_polarity', 'avg_negative_polarity',
#        'title_sentiment_polarity', 'shares'],
#       dtype='object')

# %%
#Describe the basic statistics of the data (min, max values, mean, count etc.)
news_popularity.describe()

#Just check you shares variable (which is your target) do you see some anomaly or outliers???
# Out:
#        n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.025012      0.028571      0.028571      0.028574
# 50%        0.033345      0.040004      0.040001      0.040727
# 75%        0.150831      0.334218      0.375763      0.399986
# max        0.925947      0.919999      0.926534      0.927191
#
#        global_sentiment_polarity  global_rate_positive_words  \
# count               39644.000000                39644.000000
# mean                    0.119309                    0.039625
# std                     0.096931                    0.017429
# min                    -0.393750                    0.000000
# 25%                     0.057757                    0.028384
# 50%                     0.119117                    0.039023
# 75%                     0.177832                    0.050279
# max                     0.727841                    0.155488
#
#        global_rate_negative_words  avg_positive_polarity  \
# count                39644.000000           39644.000000
# mean                     0.016612               0.353825
# std                      0.010828               0.104542
# min                      0.000000               0.000000
# 25%                      0.009615               0.306244
# 50%                      0.015337               0.358755
# 75%                      0.021739               0.411428
# max                      0.184932               1.000000
#
#        avg_negative_polarity  title_sentiment_polarity         shares
# count           39644.000000              39644.000000   39644.000000
# mean               -0.259524                  0.071425    3395.380184
# std                 0.127726                  0.265450   11626.950749
# min                -1.000000                 -1.000000       1.000000
# 25%                -0.328383                  0.000000     946.000000
# 50%                -0.253333                  0.000000    1400.000000
# 75%                -0.186905                  0.150000    2800.000000
# max                 0.000000                  1.000000  843300.000000

# %%
#Lets just remove these outliers manually for simplicity (however the correct way might be the one in the code given below)

news_popularity = news_popularity[news_popularity['shares'] < 3500]

# %%
#Read about Box plot and see how it works and what are its fundamental principles
#IGNORE THIS CODE FOR NOW, HOWEVER THIS IS ONE OF THE CORRECT WAYS OF REMOVING OUTLIERS as compared to manual removal like we did above
# BUT FOR SIMPLICITY WE USE THE ABOVE CODE 
'''

sns.boxplot(x=news_popularity['shares']) 

def Remove_Outlier_Indices(news_popularity):
    Q1 = news_popularity[' shares'].quantile(0.25)
    Q3 = news_popularity[' shares'].quantile(0.75)
    IQR = Q3 - Q1
    trueList = ~((news_popularity[' shares'] < (Q1 - 1.5 * IQR)) |(news_popularity[' shares'] > (Q3 + 1.5 * IQR)))
    return trueList

index_news_outlier = Remove_Outlier_Indices(news_popularity)
news_popularity = news_popularity[index_news_outlier]
'''

# %%
news_popularity.describe() #What do you see here? Are there extreme anomalies in the share feature?
# Out:
#        n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# count    31836.000000      31836.000000     31836.000000      31836.000000
# mean        10.417138        544.341469         0.532149          0.973018
# std          2.105005        457.196383         0.133164          0.162033
# min          2.000000          0.000000         0.000000          0.000000
# 25%          9.000000        252.000000         0.473047          1.000000
# 50%         10.000000        415.000000         0.539062          1.000000
# 75%         12.000000        710.000000         0.606907          1.000000
# max         20.000000       7764.000000         1.000000          1.000000
#
# std        0.223261      0.293035      0.284911      0.287563
# min        0.018182      0.018182      0.018182      0.018182
# 25%        0.025016      0.028572      0.025536      0.028575
# 50%        0.033348      0.040087      0.040000      0.050000
# 75%        0.153138      0.392446      0.302277      0.397540
# max        0.925947      0.919999      0.926534      0.927119
#
#        global_sentiment_polarity  global_rate_positive_words  \
# count               31836.000000                31836.000000
# mean                    0.118151                    0.039410
# std                     0.096016                    0.017306
# min                    -0.393750                    0.000000
# 25%                     0.056538                    0.028087
# 50%                     0.117400                    0.038647
# 75%                     0.176598                    0.050000
# max                     0.727841                    0.155488
#
#        global_rate_negative_words  avg_positive_polarity  \
# count                31836.000000           31836.000000
# mean                     0.016584               0.352696
# std                      0.010728               0.102072
# min                      0.000000               0.000000
# 25%                      0.009615               0.305093
# 50%                      0.015337               0.356963
# 75%                      0.021739               0.409091
# max                      0.162037               1.000000
#
#        avg_negative_polarity  title_sentiment_polarity        shares
# count           31836.000000              31836.000000  31836.000000
# mean               -0.257326                  0.066844   1399.646815
# std                 0.125571                  0.258774    712.899120
# min                -1.000000                 -1.000000      1.000000
# 25%                -0.325000                  0.000000    872.000000
# 50%                -0.250919                  0.000000   1200.000000
# 75%                -0.185362                  0.136364   1800.000000
# max                 0.000000                  1.000000   3400.000000

# %%
#This takes some time to execute
news_popularity.hist(figsize=(30, 30));

#What does these historgrams represent?

# %%
sns.boxplot(x=news_popularity['shares']) #Study about Box Plots #Whats an anomaly? What does this figure represent?

# %%
#Check the distribution of number of shares #What do you notice?
sns.distplot(news_popularity['shares'])

# %%
#This is a quick and dirty/bad code for plotting bar charts or count plots
#Try to improve this code if you can else just play around with the data, with the plots

day_wise_count = []
day_of_week = ['weekday_is_monday', 'weekday_is_tuesday',
       'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
       'weekday_is_saturday', 'weekday_is_sunday']

for item in day_of_week:
    day_wise_count.append(news_popularity[item].sum())
    print (item, ": ", news_popularity[item].sum())

plt.bar(day_of_week,height=day_wise_count,orientation='vertical')
plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')

plt.show()

#So what do you infer from the chart below??
# Out:
# weekday_is_monday :  5354
# weekday_is_tuesday :  6060
# weekday_is_wednesday :  6093
# weekday_is_thursday :  5936
# weekday_is_friday :  4601
# weekday_is_saturday :  1801
# weekday_is_sunday :  1991

# %%
#What are the plots for plotting 2 continous variables? What are continuos variables? What are discrete variables?
#Plot scatterplots for continuous variables, check for some patters
#Lets plot a scatter plot of number of tokens in content v/s shares
plt.scatter(news_popularity['n_tokens_content'], news_popularity['shares'])
#What does the plot below tell you?

# %%
# Now try to create pie charts or again bar charts for other features like data_channel_is_*
#Plot a pie chart for tech, business, entertainment, socmed etc. (we have these in the features)
#https://towardsdatascience.com/creating-a-basic-pie-chart-using-matplotlib-16dd3bf540b6
